# %%
# data 가져오기
import pandas as pd

dd = pd.read_csv('diabetes-dataset.csv')
dd
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# 데이터 전처리 
# x_data = 'outcome'열을 제외한 데이터
x_data = dd.drop('Outcome',axis=1)
x_data
# y_data = 'outcome'열
y_data = dd['Outcome']
y_data
# 학습데이터와 테스트 데이터로 분리
x_train, x_test, y_train, y_test = train_test_split(x_data,y_data, test_size=0.25)

# %%
from sklearn.svm import SVC

# %%
# 선형 커널 SVC로 모델학습
model = SVC(kernel='linear')
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# 예측 / 정확도 검증 (모델 평가)
from sklearn.metrics import accuracy_score, classification_report

predict = model.predict(x_test)
print(accuracy_score(y_test, predict))
print()
print(classification_report(y_test, predict)) # 정밀도, 재현율
# Out:
# 0.788
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       333
#            1       0.74      0.57      0.64       167
#
#     accuracy                           0.79       500
#    macro avg       0.77      0.73      0.75       500
# weighted avg       0.78      0.79      0.78       500

# %%
# heatmap - 시각화
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[15,15])
sns.heatmap(dd.corr(), square=True, annot=True, linewidths=0.1)

# %%
# 산점도 행렬 - 시각화 (Pairplot, 카테고리 지정 O)

sns.pairplot(dd, hue='Outcome', palette='husl')
